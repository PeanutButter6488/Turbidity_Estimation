# %%
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt

import sys  
sys.path.insert(0, '../dip_utils')

from matrix_utils import arr_info
from vis_utils import (vis_rgb_cube,
                       vis_hists,
                       vis_pair)

# %%
I = plt.imread('../assets/NTU14_4/6_6_14NTU1.jpg')
plt.figure()
plt.imshow(I)
arr_info(I)
# Out:
# ((1702, 1276, 3), dtype('uint8'), 0, 255)

# %%
flat = np.reshape(I, [-1, 3])

# %%
# bandwidth2 = estimate_bandwidth(flat,
# quantile=.4, n_samples=4)
# ms = MeanShift(bandwidth=bandwidth2)

# %%
nd_1 = MinMaxScaler(feature_range=(0, 1)).fit_transform(flat)

# %%
tqdm(bandwidth_1 = estimate_bandwidth(nd_1, quantile=.04, n_jobs=-1))

# %%
ms_1 = MeanShift(bandwidth = bandwidth_1 , n_jobs=-1, bin_seeding=True, cluster_all=True).fit(nd_1)

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.imshow(I)
plt.axis('off')
plt.subplot(2, 1, 2)
plt.imshow(np.reshape(labels, [851,1280]))
plt.axis('off')
