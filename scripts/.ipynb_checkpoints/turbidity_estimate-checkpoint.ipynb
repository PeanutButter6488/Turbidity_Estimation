# %% [markdown]
# ### Turbidity Estimation using test set sampled images

# %%
# %matplotlib widget
from sklearn.metrics import r2_score
from matplotlib import pyplot as plt
import numpy as np
import collections
import glob
import os
import sys 
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
sys.path.insert(0, '../dip_utils')
from matrix_utils import arr_info
from vis_utils import (vis_pair, 
                       vis_triple)
# %run watershed.ipynb
# %run calibrate.ipynb
# %run greyscale.ipynb
# %run image_stacking.ipynb
# %run whitep_elimination.ipynb

# %%
path = '../test_images/'
dest = '../stacked_test/'
clear = '../stacked_new/NTU0.jpg'

# %%
# %%bash
# cd ../stacked_test/
# rm -r *

# %%
image_stacking(path, dest)

# %%
image = []
filename = []
for dic in os.listdir(dest):
    if dic != '.ipynb_checkpoints':
        filename.append(dic)
for dic in os.listdir(dest):
    d = os.path.join(dest, dic)  # directory of water samples
    if not d.endswith('.ipynb_checkpoints'):
        img = plt.imread(d)
        image.append(img)

# %%
img_lib = {}
for i in range(len(filename)):
    img_lib[filename[i]] = image[i]

# %%
markers_lib = dict()
for img in img_lib:
    markers = watershed(dest, img)
    markers_lib[img] = markers

# %%
bottom_lib = dict()
left_lib = dict()

# %%
# Acquire the bottom and the leftmost point of the ROI
# Also acquire the right and top part of the ROI for resize purposes.
for key in markers_lib:
    bottom = np.where(markers_lib[key]==1)[0].max()
    bottom_lib[key] = bottom
    top = np.where(markers_lib[key]==2)[0].min()
    top_lib[key] = top
    left = np.where((markers_lib[key]!=1) & (markers_lib[key]!=-1))[1].min()
    left_lib[key] = left
    right = np.where((markers_lib[key]!=1) & (markers_lib[key]!=-1))[1].max()
    right_lib[key] = right
    
ref_b = bottom_lib['NTU0.jpg']
ref_t = top_lib['NTU0.jpg']
ref_l = left_lib['NTU0.jpg']
ref_r = right_lib['NTU0.jpg']
ratio_ref = (ref_b - ref_t) / (ref_r - ref_l)

# %%
# Some threshold values
envir = ['NTU19_0.jpg', 'NTU3_18.jpg', 'NTU4_05.jpg']
# 550 50 80 350
vert_thres = 500
horz_thres = 50
length = 80
dist = 300

# %%
# Avoid Extracting incorrect ROI
for key in markers_lib:
    while markers_lib[key][bottom_lib[key]-vert_thres, left_lib[key]+horz_thres] == 1:
        left_lib[key] += horz_thres
    if key in envir:
        left_lib[key] += 3*horz_thres
left_lib
# Out:
# {'NTU164.jpg': 192,
#  'NTU74_5.jpg': 260,
#  'NTU108.jpg': 199,
#  'NTU137.jpg': 153,
#  'NTU50_5.jpg': 210,
#  'NTU35_2.jpg': 205,
#  'NTU334.jpg': 241,
#  'NTU263.jpg': 253,
#  'NTU185.jpg': 222,
#  'NTU358.jpg': 121,
#  'NTU214.jpg': 224,
#  'NTU160.jpg': 166,
#  'NTU65_3.jpg': 78,
#  'NTU374.jpg': 208,
#  'NTU43_3.jpg': 204,
#  'NTU148.jpg': 209,
#  'NTU235.jpg': 193,
#  'NTU127.jpg': 120,
#  'NTU323.jpg': 131,
#  'NTU296.jpg': 158,
#  'NTU417.jpg': 183}

# %%
# Calibration
calibrated = {}
for img in img_lib:
    org = plt.imread(os.path.join(dest, img))
    org = lab_trans(clear, org)
    calibrated[img] = org

# %%
greyscale = {}
for img in img_lib:
    grey = calibrated[img]
    grey = to_single_channel(grey)
    greyscale[img] = grey

# %%
# x_left represents the ROI of the reference, while x_right represents the ROI of the sample
x_left = []
x_right = []
y_left = []
y_right = []

# %%
for key in greyscale:
    x = []
    x1 = []
    y = []
    y1 = []
    for i in range(bottom_lib[key], bottom_lib[key]-vert_thres, -1):
        x.append(i)
        y.append(np.mean(greyscale[key][i-1:i, left_lib[key]+horz_thres:left_lib[key]+horz_thres+length]))
    x_left.append(x)
    y_left.append(y)
    for i in range(bottom_lib[key], bottom_lib[key]-vert_thres, -1):
        x1.append(i)
        y1.append(np.mean(greyscale[key][i-1:i, left_lib[key]+horz_thres+dist:
                                         left_lib[key]+horz_thres+dist+length]))
    x_right.append(x1)
    y_right.append(y1)

# %%
left_lib[key]+horz_thres+dist, left_lib[key]+horz_thres+dist+length
# Out:
# (583, 663)

# %%
x_left = np.array(x_left)
x_right = np.array(x_right)
y_left = np.array(y_left)
y_right = np.array(y_right)

# %%
# plot the ratio with respect to NTU
num = []
for img in img_lib:
    img = img.replace('_', '.')
    a = img.split('NTU')
    a = [b.split('.jpg') for b in a]
    for item in a:
        item.remove("")
    num.append(a)

# %%
NTU = []
for i in num:
    for j in i:
        if len(j) != 0:
            NTU.append(float(j[0]))

# %%
f = open('../assets/theta.txt')
thresholds = f.readlines()
for i in range(len(thresholds)):
    thresholds[i] = thresholds[i].strip()
    thresholds[i] = float(thresholds[i])

# %%
diff = []
for i in range(x_left.shape[0]):
    diff.append(abs(np.mean(abs(y_right[i] - y_left[i]))))

# %%
for i in range(len(diff)):
    diff[i] -= thresholds[0]

# %%
correction = abs(thresholds[2] / thresholds[1])
correction
# Out:
# 4.295074268368753

# %%
estimated = [abs(round(diff[i]*thresholds[1]+thresholds[2], 2)) for i in range(len(diff))]

# %%
pair = dict(zip(NTU, estimated))

# %%
od_NTU = []
od_estimated = []
for key, value in sorted(pair.items()):
    od_NTU.append(key)
    od_estimated.append(value)

# %%
r2 = r2_score(od_NTU, od_estimated)
r2 = round(r2, 3)

# %%
df = pd.DataFrame(list(zip(od_NTU, od_estimated)),
               columns =['Actual_NTU', 'Estimated_NTU'])

# %%
df['R^2'] = r2
df
# Out:
#     Actual_NTU  Estimated_NTU    R^2
# 0         35.2          90.87  0.796
# 1         43.3         100.12  0.796
# 2         50.5         109.67  0.796
# 3         65.3          52.25  0.796
# 4         74.5         129.84  0.796
# 5        108.0         165.78  0.796
# 6        127.0         192.62  0.796
# 7        137.0         206.67  0.796
# 8        148.0         215.35  0.796
# 9        160.0         203.50  0.796
# 10       164.0         197.55  0.796
# 11       185.0         232.09  0.796
# 12       214.0         244.40  0.796
# 13       235.0         297.81  0.796
# 14       263.0         283.78  0.796
# 15       296.0         346.93  0.796
# 16       323.0         388.55  0.796
# 17       334.0         398.48  0.796
# 18       358.0         412.16  0.796
# 19       374.0         420.28  0.796
# 20       417.0         438.76  0.796

# %%
df.to_csv('../assets/prediction.csv')

# %%
# Figure 10
model = ols('Estimated_NTU ~ Actual_NTU', data=df).fit()

#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Estimated_NTU   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     648.7
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):           3.78e-16
# Time:                        16:40:18   Log-Likelihood:                -92.303
# No. Observations:                  21   AIC:                             188.6
# Df Residuals:                      19   BIC:                             190.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     50.2030      8.846      5.675      0.000      31.688      68.718
# Actual_NTU     0.9906      0.039     25.469      0.000       0.909       1.072
# ==============================================================================
# Omnibus:                       15.084   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.293
# Skew:                          -1.590   Prob(JB):                     0.000788
# Kurtosis:                       5.495   Cond. No.                         447.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Figure 9
#define figure size
fig = plt.figure(figsize=(12,8))

#produce regression plots
fig = sm.graphics.plot_regress_exog(model, 'Actual_NTU', fig=fig)
plt.savefig('../assets/test_fit.pdf', dpi=600)
plt.show()
# Out:
# eval_env: 1
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
